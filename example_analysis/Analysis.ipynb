# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import pickle
import seaborn as sns
import scipy.stats as stats
from pathlib import Path
from analysis import *

# %% [markdown]
# ### load data

# %%
data = load_data('bert-base')

# %% [markdown]
# ## PRETRAIN ANALYSIS (individual attention score and cross-data consistency)

# %%
plotting_pretrain(data,measure='f1')
# Out:
# tau coefficient: 0.4151126651126651 p_value 1.556575260244575e-13

# %% [markdown]
# ## FINETUNE ANALYSIS

# %% [markdown]
# #### average attention heads change over runs

# %%
overall_performance(data,run=True)
# Out:
# MEASURE: precision
# pretrain: 49.452327600297394
# negation task: 52.152027093838086 2.2050715547183284
# individual runs: [0.521995751713786, 0.5178273836333064, 0.48016464651756624, 0.5278265803617508, 0.5233815558886986, 0.5344012646344934, 0.48323744201342705, 0.5506904238457289, 0.5315153860475333, 0.5441622747275171]
# control task: 48.554356308983294 1.6522174815396466
# individual runs: [0.47660002154158776, 0.4965584301318533, 0.4799229469780733, 0.47989864479815453, 0.45423768248624363, 0.4939950076024642, 0.4725177180414664, 0.4811397729875856, 0.5098079598852819, 0.5107574464456186]
# --------------------
# MEASURE: recall
# pretrain: 5.19081444339984
# negation task: 6.61933301995195 0.7834431297945893
# individual runs: [0.057325942755666985, 0.06177856993627912, 0.05577753403670043, 0.07270774574323619, 0.0639863853198231, 0.08357816254047844, 0.06050001741007696, 0.07009405794073609, 0.06927360806434764, 0.06691127824784987]
# control task: 5.2592904523138 0.20877371929966873
# individual runs: [0.05326613043629653, 0.054522920366308014, 0.05149030258713743, 0.05161870190466242, 0.05005397123855288, 0.05334882830182109, 0.04935756816045127, 0.05114318917789616, 0.0555120303631742, 0.055615402695079905]
# --------------------
# MEASURE: f1
# pretrain: 9.022276998928655
# negation task: 11.095587583109277 1.2159494718585977
# individual runs: [0.09766378983707208, 0.10532544476433604, 0.0936320810223978, 0.12127070669260383, 0.10831843805304615, 0.13620652286000604, 0.09963994040211412, 0.11889322576485083, 0.11597987767609125, 0.11262873123840965]
# control task: 8.98512335341052 0.4424140188886672
# individual runs: [0.09130503370691284, 0.09429544651005768, 0.08678653850916859, 0.08684672914762658, 0.08315062937100468, 0.08987425535990447, 0.08455662422772753, 0.08932564012418279, 0.09518896982903266, 0.09718246855543397]
# --------------------

# %% [markdown]
# #### attention head change averaged over10 runs

# %%
head_change(data,measure='f1')
# Out:
# 12 12

# %% [markdown]
# #### The rich get richer hypothesis

# %%
rich_hypothesis(data, measure='f1',runs=True)
# Out:
# MEASURE: f1
# run:1 tau: 0.07983682983682984    p-value: 0.1556679872656248
# run:2 tau: 0.18026418026418026    p-value: 0.0013470579273164105
# run:3 tau: 0.11383061383061382    p-value: 0.04293645904329355
# run:4 tau: 0.022533022533022532    p-value: 0.6886261864793595
# run:5 tau: 0.1555944055944056    p-value: 0.005656753530277196
# run:6 tau: -0.028749028749028745    p-value: 0.6091664772812433
# run:7 tau: 0.18764568764568765    p-value: 0.0008467836571755172
# run:8 tau: -0.039821289821289824    p-value: 0.4788401904806978
# run:9 tau: 0.13247863247863248    p-value: 0.018475005365459034
# run:10 tau: 0.04254079254079254    p-value: 0.4493303091724469
# negation task: average coefficient: 0.08461538461538462 0.07869541200914797 sig.frac: 0.5
# --------------

# %% [markdown]
# #### Consistency change over 10 runs

# %%
consistency(data,'f1',runs=True)
# Out:
# MEASURE: f1
# Pretrain: tau coeffiecienty: 0.4151126651126651    p-value: 1.556575260244575e-13
# --------------
# negation run:1 tau: 0.5099067599067599    p-value: 1.2119904482613533e-19
# negation run:2 tau: 0.5304972804972805    p-value: 3.940059776406164e-21
# negation run:3 tau: 0.5155400155400155    p-value: 4.8098175979890344e-20
# negation run:4 tau: 0.47630147630147623    p-value: 2.44563271696568e-17
# negation run:5 tau: 0.5343822843822844    p-value: 2.0337093738401825e-21
# negation run:6 tau: 0.533022533022533    p-value: 2.5647622056863344e-21
# negation run:7 tau: 0.49669774669774674    p-value: 1.0179995867483873e-18
# negation run:8 tau: 0.49689199689199687    p-value: 9.870230514552267e-19
# negation run:9 tau: 0.5324397824397824    p-value: 2.832384893062701e-21
# negation run:10 tau: 0.535936285936286    p-value: 1.5589382726506948e-21
# negation task: average coefficient: 0.516161616161616 0.01963749374766129 sig.frac: 1.0
# --------------
# control run:1 tau: 0.39957264957264954    p-value: 1.1956398854801563e-12
# control run:2 tau: 0.4353146853146853    p-value: 9.825191336982435e-15
# control run:3 tau: 0.40384615384615385    p-value: 6.876327015682616e-13
# control run:4 tau: 0.40423465423465427    p-value: 6.537233061141842e-13
# control run:5 tau: 0.4020979020979021    p-value: 8.628512961876448e-13
# control run:6 tau: 0.36480186480186483    p-value: 8.726031440900502e-11
# control run:7 tau: 0.46561771561771564    p-value: 1.2276437100829425e-16
# control run:8 tau: 0.3991841491841492    p-value: 1.256951617454393e-12
# control run:9 tau: 0.42288267288267284    p-value: 5.4604123499541774e-14
# control run:10 tau: 0.39316239316239315    p-value: 2.7123569135832255e-12
# control task: average coefficient: 0.4090714840714841 0.0256459476451296 sig.frac: 1.0
# --------------

# %% [markdown]
# #### layerwise change

# %%
layerwise_change(data, measure='f1')
